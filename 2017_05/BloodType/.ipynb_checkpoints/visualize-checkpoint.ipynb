# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = pd.read_csv("out.csv")

# %%
for col in x.columns[1:]:
    plt.plot(x["gen"],x[col],label=col)
plt.legend()
plt.show()

# %%
A = ["AO","AA"]
B=["BO","BB"]
O=["OO"]
AB = ["AB"]

# %%
y = pd.DataFrame()
y["A"]=x["AA"]+x["AO"]
y["B"]=x["BB"]+x["BO"]
y["O"]=x["OO"]
y["AB"]=x["AB"]

# %%
for col in y.columns[:]:
    plt.plot(x["gen"],y[col],label=col)
plt.legend()
plt.show()

# %%
for col in x.columns[1:]:
    plt.plot(x["gen"][:50],x[col][:50],label=col)
plt.legend()
plt.show()

# %%
for col in y.columns[:]:
    plt.plot(x["gen"][:50],y[col][:50],label=col)
plt.legend()
plt.show()
